# %% [markdown]
# <a href="https://colab.research.google.com/github/havihaviplants/Artbox/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt


realEstate = [82, 83, 83.5, 83.8, 83.9, 136.1, 133.4, 130.6, 126.2, 121.1]
interestRate = [2.75, 2.75, 2.75, 2.75, 2.5, 2.25, 2.5, 2.5, 3, 3.25]

data = {'부동산' : realEstate, '금리':interestRate}

plt.scatter(df['부동산'], df['금리'])
plt.show()

# %%
df = pd.DataFrame(data)
coef = df.corr(method = 'pearson')
print(coef)
# Out:
#           부동산        금리
# 부동산  1.000000 -0.154475
# 금리  -0.154475  1.000000
